# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/Updated_Car_Sales_Data.csv")

# %%
df
# Out:
#            Car Make    Car Model  Year  Mileage       Price Fuel Type   Color  \
# 0           Hyundai       Tucson  2010    52554   44143.820    Hybrid   Black
# 1        Land Rover  Range Rover  2016   115056   25414.060    Diesel  Silver
# 2             Honda       Accord  2022    18044   28262.872  Electric  Yellow
# 3               Kia         Soul  2011    79251   28415.848    Hybrid  Orange
# 4        Volkswagen         Golf  2022    40975   31509.792  Electric  Silver
# ...             ...          ...   ...      ...         ...       ...     ...
# 22995  Aston Martin      Vantage  2021    46146  164033.000    Hybrid     Red
# 22996  Aston Martin          DBX  2017    45415  213867.000    Hybrid   White
# 22997       Porsche      Cayenne  2015    32402  145626.000    Petrol   Black
# 22998   Lamborghini    Aventador  2020    27640  224705.000    Hybrid   White
# 22999      Maserati      Levante  2016    20624  164375.000    Diesel    Blue
#
# ...

# %%
df.head(4)
# Out:
#      Car Make    Car Model  Year  Mileage      Price Fuel Type   Color  \
# 0     Hyundai       Tucson  2010    52554  44143.820    Hybrid   Black
# 1  Land Rover  Range Rover  2016   115056  25414.060    Diesel  Silver
# 2       Honda       Accord  2022    18044  28262.872  Electric  Yellow
# 3         Kia         Soul  2011    79251  28415.848    Hybrid  Orange
#
#   Transmission                                 Options/Features Condition  \
# 0    Automatic                                     Heated Seats      Used
# 1       Manual                                              GPS      Used
# 2       Manual     Bluetooth, Leather Seats, Backup Camera, GPS  Like New
# 3       Manual  Backup Camera, GPS, Heated Seats, Leather Seats       New
#
#   Accident
# 0       No
# 1       No
# 2      Yes
# 3      Yes

# %%
df.tail(6)
# Out:
#            Car Make  Car Model  Year  Mileage     Price Fuel Type  Color  \
# 22994  Aston Martin       DB11  2017     5885  139549.0    Petrol  Green
# 22995  Aston Martin    Vantage  2021    46146  164033.0    Hybrid    Red
# 22996  Aston Martin        DBX  2017    45415  213867.0    Hybrid  White
# 22997       Porsche    Cayenne  2015    32402  145626.0    Petrol  Black
# 22998   Lamborghini  Aventador  2020    27640  224705.0    Hybrid  White
# 22999      Maserati    Levante  2016    20624  164375.0    Diesel   Blue
#
#       Transmission Options/Features Condition Accident
# 22994    Automatic       Navigation      Used      Yes
# 22995       Manual    Leather Seats  Like New       No
# 22996    Automatic          Sunroof  Like New       No
# 22997    Automatic       Navigation       New      Yes
# 22998       Manual        Bluetooth      Used      Yes
# 22999    Automatic        Bluetooth       New       No

# %%
df.isnull()
# Out:
#        Car Make  Car Model   Year  Mileage  Price  Fuel Type  Color  \
# 0         False      False  False    False  False      False  False
# 1         False      False  False    False  False      False  False
# 2         False      False  False    False  False      False  False
# 3         False      False  False    False  False      False  False
# 4         False      False  False    False  False      False  False
# ...         ...        ...    ...      ...    ...        ...    ...
# 22995     False      False  False    False  False      False  False
# 22996     False      False  False    False  False      False  False
# 22997     False      False  False    False  False      False  False
# 22998     False      False  False    False  False      False  False
# 22999     False      False  False    False  False      False  False
#
#        Transmission  Options/Features  Condition  Accident
# 0             False             False      False     False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23000 entries, 0 to 22999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Car Make          23000 non-null  object
#  1   Car Model         23000 non-null  object
#  2   Year              23000 non-null  int64
#  3   Mileage           23000 non-null  int64
#  4   Price             23000 non-null  float64
#  5   Fuel Type         23000 non-null  object
#  6   Color             23000 non-null  object
#  7   Transmission      23000 non-null  object
#  8   Options/Features  23000 non-null  object
#  9   Condition         23000 non-null  object
#  10  Accident          23000 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#                Year        Mileage          Price
# count  23000.000000   23000.000000   23000.000000
# mean    2016.405826   71329.942696   46038.145075
# std        3.756306   42973.351374   64252.736726
# min     2010.000000    5015.000000    4000.832000
# 25%     2013.000000   33252.500000   14740.131000
# 50%     2017.000000   67282.500000   25489.812000
# 75%     2020.000000  108982.500000   36176.485000
# max     2023.000000  149987.000000  299922.000000

# %%
df.shape
# Out:
# (23000, 11)

# %%
df.columns
# Out:
# Index(['Car Make', 'Car Model', 'Year', 'Mileage', 'Price', 'Fuel Type',
#        'Color', 'Transmission', 'Options/Features', 'Condition', 'Accident'],
#       dtype='object')

# %%
df.drop("Year",axis=1)
# Out:
#            Car Make    Car Model  Mileage       Price Fuel Type   Color  \
# 0           Hyundai       Tucson    52554   44143.820    Hybrid   Black
# 1        Land Rover  Range Rover   115056   25414.060    Diesel  Silver
# 2             Honda       Accord    18044   28262.872  Electric  Yellow
# 3               Kia         Soul    79251   28415.848    Hybrid  Orange
# 4        Volkswagen         Golf    40975   31509.792  Electric  Silver
# ...             ...          ...      ...         ...       ...     ...
# 22995  Aston Martin      Vantage    46146  164033.000    Hybrid     Red
# 22996  Aston Martin          DBX    45415  213867.000    Hybrid   White
# 22997       Porsche      Cayenne    32402  145626.000    Petrol   Black
# 22998   Lamborghini    Aventador    27640  224705.000    Hybrid   White
# 22999      Maserati      Levante    20624  164375.000    Diesel    Blue
#
#       Transmission                                   Options/Features  \
# ...

# %%
df.fillna(0)
# Out:
#            Car Make    Car Model  Year  Mileage       Price Fuel Type   Color  \
# 0           Hyundai       Tucson  2010    52554   44143.820    Hybrid   Black
# 1        Land Rover  Range Rover  2016   115056   25414.060    Diesel  Silver
# 2             Honda       Accord  2022    18044   28262.872  Electric  Yellow
# 3               Kia         Soul  2011    79251   28415.848    Hybrid  Orange
# 4        Volkswagen         Golf  2022    40975   31509.792  Electric  Silver
# ...             ...          ...   ...      ...         ...       ...     ...
# 22995  Aston Martin      Vantage  2021    46146  164033.000    Hybrid     Red
# 22996  Aston Martin          DBX  2017    45415  213867.000    Hybrid   White
# 22997       Porsche      Cayenne  2015    32402  145626.000    Petrol   Black
# 22998   Lamborghini    Aventador  2020    27640  224705.000    Hybrid   White
# 22999      Maserati      Levante  2016    20624  164375.000    Diesel    Blue
#
# ...

# %%
df.sort_values("Mileage")
# Out:
#          Car Make Car Model  Year  Mileage      Price Fuel Type   Color  \
# 3972        Honda     Pilot  2015     5015  43651.580    Diesel     Red
# 6023     Chrysler  Pacifica  2012     5020  17527.336  Electric    Gray
# 11438      Nissan      Leaf  2014     5022  34225.728  Electric  Silver
# 1763      Porsche     Macan  2018     5022  32070.304    Hybrid   Green
# 3167         Audi        Q7  2016     5024  22912.504    Hybrid  Silver
# ...           ...       ...   ...      ...        ...       ...     ...
# 14886  Volkswagen    Tiguan  2011   149966  13472.560  Gasoline  Orange
# 3998       Jaguar    I-Pace  2016   149974  21560.780  Electric   Green
# 10612        Fiat     Panda  2013   149980  27138.296    Hybrid     Red
# 3173      Hyundai      Kona  2011   149983  20572.712  Gasoline  Orange
# 12820       Mazda    Mazda6  2010   149987  48612.630  Gasoline     Red
#
#       Transmission                                   Options/Features  \
# ...

# %%
df.loc[3]
# Out:
# Car Make                                                        Kia
# Car Model                                                      Soul
# Year                                                           2011
# Mileage                                                       79251
# Price                                                     28415.848
# Fuel Type                                                    Hybrid
# Color                                                        Orange
# Transmission                                                 Manual
# Options/Features    Backup Camera, GPS, Heated Seats, Leather Seats
# Condition                                                       New
# Accident                                                        Yes
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# Car Make                                                        Kia
# Car Model                                                      Soul
# Year                                                           2011
# Mileage                                                       79251
# Price                                                     28415.848
# Fuel Type                                                    Hybrid
# Color                                                        Orange
# Transmission                                                 Manual
# Options/Features    Backup Camera, GPS, Heated Seats, Leather Seats
# Condition                                                       New
# Accident                                                        Yes
# Name: 3, dtype: object

# %%
df["Year"].mean()
# Out:
# np.float64(2016.4058260869565)

# %%
df["Price"].max()
# Out:
# 299922.0

# %%
df["Price"].min()
# Out:
# 4000.832
